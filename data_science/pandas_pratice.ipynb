# %%
import pandas as pd

# %%
df = pd.read_csv("data/weather_data.csv").drop(columns=["Unnamed: 0"])

# %%
df.head(2)
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26  25.08
# 1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05  25.95  24.37
#
#      NOV    DEC
# 0  21.73  18.95
# 1  21.33  18.78

# %%
df.tail(2)
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17  27.72
# 116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12  28.11
#
#        OCT    NOV    DEC
# 115  26.81  23.90  21.89
# 116  27.24  23.92  21.47

# %%
df[2:5]
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63  26.34  24.57
# 3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73  25.84  24.36
# 4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47  26.29  26.16
#
#      NOV    DEC
# 2  20.96  18.29
# 3  21.07  18.84
# 4  22.07  18.71

# %%
df.columns
# Out:
# Index(['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP',
#        'OCT', 'NOV', 'DEC'],
#       dtype='object')

# %%
# df.JAN
df['JAN'].head(5)
# Out:
# 0    17.99
# 1    19.00
# 2    18.32
# 3    17.77
# 4    17.40
# Name: JAN, dtype: float64

# %%
type(df["FEB"])
# Out:
# pandas.core.series.Series

# %%
df[["YEAR","JAN","FEB","MAR","APR"]].tail(10)
# Out:
#      YEAR    JAN    FEB    MAR    APR
# 107  2008  18.49  19.83  24.43  26.54
# 108  2009  19.79  21.66  24.55  27.35
# 109  2010  19.15  21.23  26.53  28.40
# 110  2011  18.32  20.79  24.11  26.10
# 111  2012  18.25  20.43  23.98  26.89
# 112  2013  18.88  21.07  24.53  26.97
# 113  2014  18.81  20.35  23.34  26.91
# 114  2015  19.02  21.23  23.52  26.52
# 115  2016  20.92  23.58  26.61  29.56
# 116  2017  20.59  23.08  25.58  29.17

# %%
df["JAN"].mean()
# Out:
# 18.42324786324786

# %%
df.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   117.000000  117.000000  117.000000  117.000000  117.000000
# mean   1959.000000   18.423248   20.137949   23.434188   26.514103
# std      33.919021    0.612963    0.900944    0.862825    0.750740
# min    1901.000000   17.250000   17.790000   21.780000   24.840000
# 25%    1930.000000   18.070000   19.470000   22.840000   26.000000
# 50%    1959.000000   18.350000   19.990000   23.330000   26.540000
# 75%    1988.000000   18.720000   20.550000   23.930000   26.910000
# max    2017.000000   20.920000   23.580000   26.610000   29.560000
#
#               MAY         JUN         JUL         AUG         SEP         OCT  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    28.386410   28.300940   27.369231   26.940085   26.342650   24.742051
# std      0.644678    0.460603    0.345920    0.348876    0.387789    0.563152
# ...

# %%
df[df["JAN"]>20]
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 115  2016  20.92  23.58  26.61  29.56  30.41  29.70  28.18  28.17  27.72
# 116  2017  20.59  23.08  25.58  29.17  30.47  29.44  28.31  28.12  28.11
#
#        OCT    NOV    DEC
# 115  26.81  23.90  21.89
# 116  27.24  23.92  21.47

# %%
df[["YEAR","JAN"]][df["JAN"]>=df["JAN"].mean()].tail(5)
# Out:
#      YEAR    JAN
# 112  2013  18.88
# 113  2014  18.81
# 114  2015  19.02
# 115  2016  20.92
# 116  2017  20.59

# %%
df.index
# Out:
# RangeIndex(start=0, stop=117, step=1)

# %%
df.set_index("YEAR", inplace=True)

# %%
df.loc[2000]
# Out:
# JAN    18.87
# FEB    19.78
# MAR    23.22
# APR    27.27
# MAY    28.92
# JUN    28.02
# JUL    27.34
# AUG    26.98
# SEP    26.53
# OCT    25.58
# NOV    22.75
# DEC    19.66
# Name: 2000, dtype: float64

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26
# 1    1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05  25.95
# 2    1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63  26.34
# 3    1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73  25.84
# 4    1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47  26.29
# 5    1906  17.50  19.14  22.21  26.53  29.06  28.02  27.46  26.82  26.23
# 6    1907  19.27  19.42  22.03  26.98  27.52  27.66  27.28  26.38  26.26
# 7    1908  18.35  19.73  22.93  27.06  28.07  28.49  27.16  26.41  25.74
# 8    1909  17.79  19.05  23.40  25.76  27.97  27.67  26.56  26.43  25.47
# 9    1910  18.14  19.72  22.90  25.96  28.36  27.72  26.93  26.61  25.98
# 10   1911  18.52  19.18  22.05  26.00  28.55  28.02  27.44  27.04  26.22
# 11   1912  18.60  20.84  22.93  26.21  28.30  28.53  27.49  26.68  25.81
# ...
