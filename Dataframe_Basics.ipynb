# %%
import pandas as pd
#Read CSV
zomatoDf = pd.read_csv("datasets/zomato.csv")

# %%
zomatoDf
# Out:
#       Restaurant_ID                           Restaurant_Name  Country_Code  \
# 0           6317637                          Le Petit Souffle           162
# 1           6304287                          Izakaya Kikufuji           162
# 2           6300002                    Heat - Edsa Shangri-La           162
# 3           6318506                                      Ooma           162
# 4           6314302                               Sambo Kojin           162
# 5          18189371                              Din Tai Fung           162
# 6           6300781                                Buffet 101           162
# 7           6301290                                   Vikings           162
# 8           6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9           6314987                                  Locavore           162
# 10          6309903                          Silantro Fil-Mex           162
# ...

# %%
#Create Data Frame from a dictionary
zomato_data = {
	'restaurant' : ['Nasi and Me','Thai House','Phobidden Fruit'],
	'rating' : [4.2,4.1,4.6],
	'cuisine' : ['Asian','Thai','Vietnemese']
}
df=pd.DataFrame(zomato_data)
df
# Out:
#         restaurant  rating     cuisine
# 0      Nasi and Me     4.2       Asian
# 1       Thai House     4.1        Thai
# 2  Phobidden Fruit     4.6  Vietnemese

# %%
#Dimensions of a dataframe
row,columns=df.shape
print("Data frame has "+str(row)+" rows and "+str(columns)+" columns")
# Out:
# Data frame has 3 rows and 3 columns

# %%
#First n rows
zomatoDf.head(2)
# Out:
#    Restaurant_ID   Restaurant_Name  Country_Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality_Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...           Currency Has_Table_booking  \
# 0  French, Japanese, Desserts  ...   Botswana Pula(P)               Yes
# 1                    Japanese  ...   Botswana Pula(P)               Yes
#
# ...

# %%
#Last n rows
zomatoDf.tail(2)
# Out:
#       Restaurant_ID           Restaurant_Name  Country_Code       City  \
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality_Verbose  Longitude   Latitude         Cuisines  ...   \
# 9549  Kuruí_eôme, ÛÁstanbul  29.036019  41.057979  Restaurant Cafe  ...
# 9550         Moda, ÛÁstanbul  29.026016  40.984776             Cafe  ...
#
#               Currency Has_Table_booking Has_Online_delivery  \
# 9549  Turkish Lira(TL)                No                  No
# 9550  Turkish Lira(TL)                No                  No
#
#      Is_delivering_now Switch_to_order_menu Price_range  Aggregate_rating  \
# ...

# %%
#Slicing of a dataframe
zomatoDf[3:7]
# Out:
#    Restaurant_ID Restaurant_Name  Country_Code              City  \
# 3        6318506            Ooma           162  Mandaluyong City
# 4        6314302     Sambo Kojin           162  Mandaluyong City
# 5       18189371    Din Tai Fung           162  Mandaluyong City
# 6        6300781      Buffet 101           162        Pasay City
#
#                                              Address  \
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
# 5  Ground Floor, Mega Fashion Hall, SM Megamall, ...
# 6  Building K, SM By The Bay, Sunset Boulevard, M...
#
#                                           Locality  \
# 3           SM Megamall, Ortigas, Mandaluyong City
# 4           SM Megamall, Ortigas, Mandaluyong City
# 5           SM Megamall, Ortigas, Mandaluyong City
# 6  SM by the Bay, Mall of Asia Complex, Pasay City
#
#                                     Locality_Verbose   Longitude   Latitude  \
# ...

# %%
#Schema of dataframe
zomatoDf.columns
# Out:
# Index(['Restaurant_ID', 'Restaurant_Name', 'Country_Code', 'City', 'Address',
#        'Locality', 'Locality_Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average_Cost_for_two', 'Currency', 'Has_Table_booking',
#        'Has_Online_delivery', 'Is_delivering_now', 'Switch_to_order_menu',
#        'Price_range', 'Aggregate_rating', 'Rating_color', 'Rating_text',
#        'Votes'],
#       dtype='object')

# %%
zomatoDf['Restaurant_Name'].head(5)
# Out:
# 0          Le Petit Souffle
# 1          Izakaya Kikufuji
# 2    Heat - Edsa Shangri-La
# 3                      Ooma
# 4               Sambo Kojin
# Name: Restaurant_Name, dtype: object

# %%
#Selecting handful of columns
zomatoDf[['Restaurant_Name','City','Cuisines']].head(5)
# Out:
#           Restaurant_Name              City                          Cuisines
# 0        Le Petit Souffle       Makati City        French, Japanese, Desserts
# 1        Izakaya Kikufuji       Makati City                          Japanese
# 2  Heat - Edsa Shangri-La  Mandaluyong City  Seafood, Asian, Filipino, Indian
# 3                    Ooma  Mandaluyong City                   Japanese, Sushi
# 4             Sambo Kojin  Mandaluyong City                  Japanese, Korean

# %%
#MaX Of a column
zomatoDf['Aggregate_rating'].max()
# Out:
# 4.9

# %%
zomatoDf.describe()
# Out:
#        Restaurant_ID  Country_Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average_Cost_for_two  Price_range  Aggregate_rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
#Filtering
zomatoDf[zomatoDf.Aggregate_rating<3.0].head(3)
# Out:
#     Restaurant_ID        Restaurant_Name  Country_Code            City  \
# 30        6600060         Sandubas Cafí©            30       Brasí_lia
# 58        7305048  Quiosque Chopp Brahma            30  Rio de Janeiro
# 69        6710645       Cantinho da Gula            30      Sí£o Paulo
#
#                                               Address    Locality  \
# 30  Edifí_cio Josí© Severo, SCS 6, Bloco A, Loja 9...     Asa Sul
# 58  Madureira Shopping - Loja 289/290, Piso 2, Est...   Madureira
# 69  Rua Pedroso Alvarenga, 522, Itaim Bibi, Sí£o P...  Itaim Bibi
#
#              Locality_Verbose  Longitude   Latitude             Cuisines  \
# 30         Asa Sul, Brasí_lia -47.890167 -15.797000      Brazilian, Cafe
# 58  Madureira, Rio de Janeiro -43.341164 -22.870413  Bar Food, Brazilian
# 69     Itaim Bibi, Sí£o Paulo -46.675667 -23.581000            Brazilian
#
#     ...             Currency Has_Table_booking Has_Online_delivery  \
# ...

# %%
#More filters
zomatoDf[['Restaurant_Name','Average_Cost_for_two','City']][zomatoDf.Aggregate_rating==zomatoDf.Aggregate_rating.max()]
# Out:
#                                  Restaurant_Name  Average_Cost_for_two  \
# 3                                           Ooma                  1500
# 8       Spiral - Sofitel Philippine Plaza Manila                  6000
# 10                              Silantro Fil-Mex                   800
# 39                                    Coco Bambu                   230
# 48                            Braseiro da Gíçvea                   100
# 50                             Garota de Ipanema                   120
# 124                           Rae's Coastal Cafe                    40
# 175                      Shorts Burger and Shine                    10
# 213                                 Oakwood Cafe                    10
# 235                          Tantra Asian Bistro                    25
# 250                                     The Cafe                    25
# 304               Atlanta Highway Seafood Market                    25
# ...

# %%
#Logical operators
bangaloreDF=zomatoDf[(zomatoDf.City=='Bangalore') & (zomatoDf.Aggregate_rating>4.5)]
bangaloreDF
# Out:
#      Restaurant_ID                   Restaurant_Name  Country_Code       City  \
# 727          58268  The Fatty Bao - Asian Gastro Bar             1  Bangalore
# 728          51705                              Toit             1  Bangalore
# 733       18359919                            Onesta             1  Bangalore
# 734       18439634                ECHOES Koramangala             1  Bangalore
# 735          51040                          Truffles             1  Bangalore
# 739          56618         AB's - Absolute Barbecues             1  Bangalore
# 741       18366652                            Onesta             1  Bangalore
#
#                                                Address               Locality  \
# 727  610, 3rd Floor, 12th Main, Off 80 Feet Road, I...            Indiranagar
# 728  298, Namma Metro Pillar 62, 100 Feet Road, Ind...            Indiranagar
# 733  Site 15, 15th Cross, 100 Feet Road, 4th Phase,...               JP Nagar
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-dd39d326d034> in <module>()
# ----> 1 df=bangaloreDF.set_index['Restaurant_Name']
#
# TypeError: 'method' object is not subscriptable
